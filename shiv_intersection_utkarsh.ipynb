# %%
import os
import pyspark
import math
from pyspark.sql import SparkSession
from pyspark.sql.functions import substring

# %%
import pandas as pd
import numpy as np
import datetime

# %%
def read_parquet_folder_as_pandas(path, verbosity=1):
  files = [f for f in os.listdir(path) if f.endswith("parquet")]
#   files = files[:50]

  if verbosity > 0:
    print("{} parquet files found. Beginning reading...".format(len(files)), end="")
    start = datetime.datetime.now()

  df_list = [pd.read_parquet(os.path.join(path, f)) for f in files]
  df = pd.concat(df_list, ignore_index=True)

  if verbosity > 0:
    end = datetime.datetime.now()
    print(" Finished. Took {}".format(end-start))
  return df

# %%
df = read_parquet_folder_as_pandas("spotifymillion.parquet")
# Out:
# 334 parquet files found. Beginning reading... Finished. Took 0:02:42.228440

# %%
df2 = read_parquet_folder_as_pandas("1.2MtracksFeaturesParquet")
# Out:
# 3 parquet files found. Beginning reading... Finished. Took 0:00:03.136206

# %%
df1 = df.drop(columns=["playlist_name","playlist_id","artist_uri"])
df1 = df1.drop_duplicates()

# %%
df1 = df1.drop(columns=["artist_name"])
# Out:
#                                 track_name  \
# 0                          Home For A Rest
# 1                                Political
# 2            (Putting Up With) The Joneses
# 3                              The Old Sod
# 4                                Homelands
# ...                                    ...
# 66345868  Chaotic Punishment (Bonus Track)
# 66345874                    Bombs of Death
# 66346380                            Konoha
# 66346410                                Up
# 66346411                            Lifted
#
#                                      track_uri
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 66345868  spotify:track:0Ega3SDrGwR4FBxWO3PCRc
# 66345874  spotify:track:0QMzHVx4E8mTX2ptrkKyXF
# 66346380  spotify:track:7kgFXzdLiKnDV4GytHe1sb
# 66346410  spotify:track:1t9A2GMNIzrADt8QMgmLQI
# 66346411  spotify:track:5g7MsdXdtaGDleD2V1glIf
#
# [2262292 rows x 2 columns]

# %%
df1 = df1.dropna()
df1['track_uri'] = df1['track_uri'].map(lambda name: name[14:])

# %%
df2 = df2[["id","name"]]
# Out:
#                             id                              name
# 0       5EjHf83FVd53WFr8yfErUi       Sittin' On Top of The World
# 1       4QQlmPMDpOSB9DNFYzsDzU                 Am I Born To Die?
# 2       3DUFMqtynem6XMXTLkR3wf                    I'm Going Home
# 3       4kRGPeHDulsh4hg3barZH3                    Never Far Away
# 4       0jVepxXjNtS5eldyPcmFK3  Christmas Time Will Soon Be Over
# ...                        ...                               ...
# 972473  4RQmq0NSmQsnkmruH7gUbT                         Jump Jump
# 972474  7i5fOTOt0VQpXPoaG71ILH              Goodnight And I Wish
# 972475  4dp5Wv6ihYCW7PlTyZpEep                Wayfaring Stranger
# 972476  3wxPT46lvtnmggDJS03DIl   Like A Songbird That Has Fallen
# 972477  6ow1ERTmrCPg1UXqJoDa0Y           I Wish My Baby Was Born
#
# [972478 rows x 2 columns]

# %%
df2.drop_duplicates()
# Out:
#                             id                              name
# 0       5EjHf83FVd53WFr8yfErUi       Sittin' On Top of The World
# 1       4QQlmPMDpOSB9DNFYzsDzU                 Am I Born To Die?
# 2       3DUFMqtynem6XMXTLkR3wf                    I'm Going Home
# 3       4kRGPeHDulsh4hg3barZH3                    Never Far Away
# 4       0jVepxXjNtS5eldyPcmFK3  Christmas Time Will Soon Be Over
# ...                        ...                               ...
# 972473  4RQmq0NSmQsnkmruH7gUbT                         Jump Jump
# 972474  7i5fOTOt0VQpXPoaG71ILH              Goodnight And I Wish
# 972475  4dp5Wv6ihYCW7PlTyZpEep                Wayfaring Stranger
# 972476  3wxPT46lvtnmggDJS03DIl   Like A Songbird That Has Fallen
# 972477  6ow1ERTmrCPg1UXqJoDa0Y           I Wish My Baby Was Born
#
# [972478 rows x 2 columns]

# %%
df1.columns = ["name","id"]
df1
# Out:
#                                       name                      id
# 15                             Close To Me  4xiyq1iRdsxuU1BPUJ490Z
# 16                      Friday I'm In Love  4QlzkaRHtU8gAdwqjWmO8n
# 17                      Sometime To Return  4UTEaqefy5lDXf9ZACe4lU
# 18                       Never Really Been  0iZGBAHycWtEQPESPJT95n
# 19                        Obscurity Knocks  6Pbbz7hVhl3F8abGVDt06H
# ...                                    ...                     ...
# 66345868  Chaotic Punishment (Bonus Track)  0Ega3SDrGwR4FBxWO3PCRc
# 66345874                    Bombs of Death  0QMzHVx4E8mTX2ptrkKyXF
# 66346380                            Konoha  7kgFXzdLiKnDV4GytHe1sb
# 66346410                                Up  1t9A2GMNIzrADt8QMgmLQI
# 66346411                            Lifted  5g7MsdXdtaGDleD2V1glIf
#
# [2262278 rows x 2 columns]

# %%
joined = df1.set_index("id").join(df2.set_index("id"), how="inner", lsuffix='_1', rsuffix='_2')

# %%
joined
# Out:
#                                                           name_1  \
# id
# 2EEinN4Zk8MUv4OQuLsTBj  Age Of Consent - 2015 Remastered Version
# 4tPHC7YsU3LInUYcIe2UIi                                     Crash
# 3uVCJvMFKmsj9P44vNHfx1                           Grey Cell Green
# 20dP2DaMHIAmwWAbp7peSr                         pick up the phone
# 0ADG9OgdVTL7fgREP75BrZ                            Ain't My Fault
# ...                                                          ...
# 3dVeByUPeuucOUPf4u8waf                           Bar Room Beauty
# 4XqShMPgP8mqtMCN0U4cL6                     Can't Say I'll Change
# 06DhQuICVfYahs8dqvDDqu        I'll Be Your Rock (At Rock Bottom)
# 7J0dxYRp4k7KUOt85MmcDs                                    Podunk
# 74KFLplhh0biOnnGN5KwfD                     El Cielo de Chihuahua
#
#                                                     name_2
# id
# 2EEinN4Zk8MUv4OQuLsTBj      Age of Consent - 2015 Remaster
# 4tPHC7YsU3LInUYcIe2UIi                               Crash
# 3uVCJvMFKmsj9P44vNHfx1                     Grey Cell Green
# 20dP2DaMHIAmwWAbp7peSr                   pick up the phone
# 0ADG9OgdVTL7fgREP75BrZ                      Ain't My Fault
# ...                                                    ...
# 3dVeByUPeuucOUPf4u8waf                     Bar Room Beauty
# 4XqShMPgP8mqtMCN0U4cL6               Can't Say I'll Change
# 06DhQuICVfYahs8dqvDDqu  I'll Be Your Rock (At Rock Bottom)
# 7J0dxYRp4k7KUOt85MmcDs                              Podunk
# 74KFLplhh0biOnnGN5KwfD               El Cielo de Chihuahua
#
# [106985 rows x 2 columns]

# %%
joined[joined["name_1"] != joined["name_2"]]
# Out:
#                                                                    name_1  \
# id
# 2EEinN4Zk8MUv4OQuLsTBj           Age Of Consent - 2015 Remastered Version
# 5uDASfU19gDxSjW8cnCaBp                                         Chill Bill
# 2rzBvHM9h36Tpdj7Jdajka                                 Wild for the Night
# 000xQL6tZNLJzIrtIgxqSl                                     Still Got Time
# 6pV8yBEHeu7A7lkttIjM2g                   Waste Away (feat. Devon Baldwin)
# ...                                                                   ...
# 2YmyyLojlTIhiF6NT6rgcA  Deux Arabesques, L. 66: I. Andantino con moto ...
# 2mxIgrE8m3BvrtuBfGAABj                              All I Need - Main Mix
# 5scx9EiTkPtIpdsUzxxWvK  Song of India ("Countless diamonds are hidden ...
# 6UildWDUbdBBHLgYJ24WPt                            The Right Place To Fade
# 752wM7wKh6Q3xBRIO7VGQY                               Bull In A China Shop
#
#                                                                    name_2
# id
# 2EEinN4Zk8MUv4OQuLsTBj                     Age of Consent - 2015 Remaster
# 5uDASfU19gDxSjW8cnCaBp               Chill Bill (feat. J. Davi$ & Spooks)
# 2rzBvHM9h36Tpdj7Jdajka  Wild for the Night (feat. Skrillex & Birdy Nam...
# 000xQL6tZNLJzIrtIgxqSl               Still Got Time (feat. PARTYNEXTDOOR)
# 6pV8yBEHeu7A7lkttIjM2g                   waste away (feat. Devon Baldwin)
# ...                                                                   ...
# 2YmyyLojlTIhiF6NT6rgcA  2 Arabesques, L. 66: No. 1 in E Major (Orchest...
# 2mxIgrE8m3BvrtuBfGAABj        All I Need (feat. Wale & Tawiah) - Main Mix
# 5scx9EiTkPtIpdsUzxxWvK  "Song of India (""Countless diamonds are hidde...
# 6UildWDUbdBBHLgYJ24WPt                            The Right Place to Fade
# 752wM7wKh6Q3xBRIO7VGQY                               Bull in a China Shop
#
# [9208 rows x 2 columns]

# %%
joined
